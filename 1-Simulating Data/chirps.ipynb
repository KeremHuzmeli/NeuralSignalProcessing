# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d

# %%
pnts = 10000
srate = 1024
time = np.arange(0, pnts) / srate

freqmod = np.linspace(5, 15, pnts)

signal = np.sin(2*np.pi*(time + np.cumsum(freqmod)/srate))

# %%
plt.subplot(211)
plt.plot(time, freqmod, "r")
plt.xlabel("Time (s)")
plt.ylabel("Frequency (Hz)")
plt.title("Instantaneous Frequency")

plt.subplot(212)
plt.plot(time, signal, "k")
plt.xlabel("Time (s)")
plt.ylabel("Amplitude (a.u.)")
plt.title("Signal (chirp)")

plt.tight_layout()

# %%
k = 10
x = np.linspace(1, 10, 10)
y = np.random.rand(10)
f = interp1d(x, y)

xNew = np.linspace(1, k , pnts)
freqmod = 20 * f(xNew)

signal = np.sin(2*np.pi*(time + np.cumsum(freqmod)/srate))

# %%
plt.subplot(211)
plt.plot(time, freqmod, "r")
plt.xlabel("Time (s)")
plt.ylabel("Frequency (Hz)")
plt.title("Instantaneous Frequency")

plt.subplot(212)
plt.plot(time, signal, "k")
plt.xlabel("Time (s)")
plt.ylabel("Amplitude (a.u.)")
plt.title("Signal (chirp)")

plt.tight_layout()
